# %%
from urllib.parse import urlencode, urlparse, parse_qsl
import numpy as np
import pandas as pd
import requests
from sodapy import Socrata

# CDC API Keys and Token
from config import key_id, app_token, user_name, user_password

# %%
# Example authenticated client (needed for non-public datasets):
client = Socrata("chronicdata.cdc.gov",
                  app_token,
                  username = user_name,
                  password= user_password)
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("g4ie-h725", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# 'https://soda.demo.socrata.com/resource/6yvf-kk3n.json?region=Virgin Islands region&source=pr'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-666a5da89711> in <module>
#       1 # Example authenticated client (needed for non-public datasets):
# ----> 2 client = Socrata("chronicdata.cdc.gov",
#       3                   MyAppToken = app_token,
#       4                   username = user_name,
#       5                   password= user_password)
#
# TypeError: __init__() got an unexpected keyword argument 'MyAppToken'

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cdc.gov", None)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("bi63-dtpu", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      year                                    _113_cause_name  \
# 0    2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 1    2017  Nephritis, nephrotic syndrome and nephrosis (N...
# 2    2016  Nephritis, nephrotic syndrome and nephrosis (N...
# 3    2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 4    2000  Intentional self-harm (suicide) (*U03,X60-X84,...
# ..    ...                                                ...
# 995  2009  Intentional self-harm (suicide) (*U03,X60-X84,...
# 996  2008                  Influenza and pneumonia (J09-J18)
# 997  2008  Nephritis, nephrotic syndrome and nephrosis (N...
# 998  2007  Intentional self-harm (suicide) (*U03,X60-X84,...
# 999  2005  Intentional self-harm (suicide) (*U03,X60-X84,...
#
#                   cause_name                 state deaths  aadr
# 0             Kidney disease               Vermont     21   2.6
# ...

# %%
results_2011 = results_df[results_df['state']=='Illinois']
results_2011
# Out:
#       year                                    _113_cause_name  \
# 167   2006  Intentional self-harm (suicide) (*U03,X60-X84,...
# 180   2003  Intentional self-harm (suicide) (*U03,X60-X84,...
# 192   2004  Intentional self-harm (suicide) (*U03,X60-X84,...
# 197   2000  Intentional self-harm (suicide) (*U03,X60-X84,...
# 219   1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# 241   2007  Intentional self-harm (suicide) (*U03,X60-X84,...
# 243   2005  Intentional self-harm (suicide) (*U03,X60-X84,...
# 290   2010  Intentional self-harm (suicide) (*U03,X60-X84,...
# 300   2009  Intentional self-harm (suicide) (*U03,X60-X84,...
# 314   2002  Intentional self-harm (suicide) (*U03,X60-X84,...
# 316   2001  Intentional self-harm (suicide) (*U03,X60-X84,...
# 326   2011  Intentional self-harm (suicide) (*U03,X60-X84,...
# 329   2008  Intentional self-harm (suicide) (*U03,X60-X84,...
# 396   2012  Intentional self-harm (suicide) (*U03,X60-X84,...
# ...

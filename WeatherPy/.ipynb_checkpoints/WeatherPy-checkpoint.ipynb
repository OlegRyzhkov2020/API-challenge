# %% [markdown]
# # WeatherPy

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats =['retina']

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import time
import pycountry
import seaborn as sns
from scipy.stats import linregress
from matplotlib.pylab import rcParams

sns.set()
plt.rc('lines', linewidth=1)
rcParams['figure.figsize'] = 12,6

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Set the data display options in a float format
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print('Number of unique cities', len(cities))

# Creating random dataset for testing
test_cities = np.random.choice(cities, 100)
print('\nRandom array of 100 cities for testing:', [test_cities[i].title() for i in range(len(test_cities))])
# Out:
# Number of unique cities 643
#
# Random array of 100 cities for testing: ['Karaul', 'Sahrak', 'Paradwip', 'Umm Lajj', 'Gladstone', 'San Andres', 'Pierre', 'Lavrentiya', 'Shchelyayur', 'Sterling', 'Ayia Galini', 'Zavetnoye', 'Junction City', 'Takoradi', 'Armacao Dos Buzios', 'Sabang', 'Fairhope', 'Galle', 'Bhadra', 'Cairo', 'Alice Springs', 'Kuche', 'Kireyevsk', 'Illoqqortoormiut', 'Butaritari', 'Bondo', 'Martapura', 'Ilo', 'Nome', 'Hilo', 'Koygorodok', 'Christchurch', 'Doha', 'Cairo', 'Vengerovo', 'Tura', 'Minnedosa', 'Asfi', 'Srandakan', 'Enid', 'Gat', 'Thompson', 'Husavik', 'Bubaque', 'Rikitea', 'Saint-Paul', 'Provideniya', 'Fevralsk', 'Guerrero Negro', 'Kjollefjord', 'Trairi', 'Kati', 'Nelson Bay', 'Thompson', 'Phulabani', 'Kuche', 'Edinet', 'Gwadar', 'Moranbah', 'Mangrol', 'Aksarka', 'Candelaria', 'Aojiang', 'Kalmunai', 'Grand River South East', 'Saint-Augustin', 'Khilok', 'Bageshwar', 'Biak', 'Stribro', 'Suntar', 'Babanusah', 'Alice Springs', 'Esperance', 'Puerto Ayora', 'Bredasdorp', 'Lompoc', 'Arlit', 'La Ronge', 'Saldanha', 'Dongli', 'Marcona', 'Flin Flon', 'Torbay', 'Vao', 'Kruisfontein', 'Homer', 'Marhaura', 'Taolanaro', 'Longyearbyen', 'Mosetse', 'Filadelfia', 'Dawei', 'Mwinilunga', 'Polson', 'Paradwip', 'Krasnoselkup', 'Urengoy', 'Koygorodok', 'Huntingdon']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=c6f6a86e8a097acc28080af8686cb857&units=metric&q='

# %%
# set up lists to hold reponse info
lat = []
lon = []
temp_max = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
found_cities = []
not_found_cities = []

# %%
# Loop through the list of cities and perform a request for data on each
print('Beginning data retrieval for ', len(cities), ' cities\n')
for city in test_cities:
    response = requests.get(query_url + city).json()
#    print ('Processing request for city:', city)
    try:
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        found_cities.append(city)
    except:
        not_found_cities.append(city)
        pass
    if len(found_cities) % 40 == 0: 
        print('Processing records: found ', len(found_cities),' cities, skipped ', len(not_found_cities), 'cities')
print('\nData retrieval is over\n')
print('Number of skipped cities = ', len(not_found_cities))
print([not_found_cities[i].title() for i in range(len(not_found_cities))])
# Out:
# Beginning data retrieval for  643  cities
#
# Processing records: found  0  cities, skipped  1 cities
# Processing records: found  0  cities, skipped  2 cities
# Processing records: found  0  cities, skipped  3 cities
# Processing records: found  40  cities, skipped  7 cities
# Processing records: found  40  cities, skipped  8 cities
# Processing records: found  80  cities, skipped  13 cities
#
# Data retrieval is over
#
# Number of skipped cities =  14
# ['Karaul', 'Sahrak', 'Paradwip', 'Shchelyayur', 'Armacao Dos Buzios', 'Kuche', 'Illoqqortoormiut', 'Fevralsk', 'Kuche', 'Grand River South East', 'Babanusah', 'Marcona', 'Taolanaro', 'Paradwip']

# %%
# create a data dict from found_cities, lat, lon, temp_max, humidity, cloudiness, wind_speed, country
weather_dict = {
    "City": found_cities,
    "Lat": lat,
    "Lng": lon,
    "Max_Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind_Speed": wind_speed,
    "Country_Code": country
                }

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
def country_flag(df):
    if (len(df['Country_Code'])==2 and df['Country_Code'] in list_alpha_2):
        return pycountry.countries.get(alpha_2=df['Country_Code']).name
    else:
        return 'Invalid Code'

# %%
# create a data frame from data dict
weather_data = pd.DataFrame(weather_dict)
weather_data['City'] = weather_data['City'].map(str.upper)  
list_alpha_2 = [i.alpha_2 for i in list(pycountry.countries)]
weather_data['Country_Name'] = weather_data.apply(country_flag, axis = 1)
weather_data['UTC_DateTime']= [datetime.datetime.utcfromtimestamp(date[i]) for i in range(len(date))]
weather_data.head()
# Out:
#          City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0    UMM LAJJ  25.02   37.27     28.02        72           0        2.50
# 1   GLADSTONE -23.85  151.25      9.00        57           0        2.60
# 2  SAN ANDRES  12.58  -81.70     30.00        74          20        4.10
# 3      PIERRE  44.37 -100.35     32.22        24           1        3.60
# 4  LAVRENTIYA  65.58 -171.00     10.63        77          99        2.01
#
#   Country_Code        Country_Name        UTC_DateTime
# 0           SA        Saudi Arabia 2020-07-16 21:34:27
# 1           AU           Australia 2020-07-16 21:36:18
# 2           CO            Colombia 2020-07-16 21:36:18
# 3           US       United States 2020-07-16 21:34:05
# 4           RU  Russian Federation 2020-07-16 21:36:19

# %%
weather_data.count()
# Out:
# City            86
# Lat             86
# Lng             86
# Max_Temp        86
# Humidity        86
# Cloudiness      86
# Wind_Speed      86
# Country_Code    86
# Country_Name    86
# UTC_DateTime    86
# dtype: int64

# %%
weather_data.describe()
# Out:
#          Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed
# count  86.00   86.00     86.00     86.00       86.00       86.00
# mean   23.82   16.11     20.15     73.56       45.76        3.45
# std    31.49   93.01      8.46     16.58       38.47        2.22
# min   -43.53 -173.30      0.00     21.00        0.00        0.19
# 25%     3.25  -74.20     13.00     64.00        1.00        1.65
# 50%    26.98   27.33     22.80     76.00       41.00        3.10
# 75%    50.98   83.79     26.69     87.00       83.50        4.71
# max    78.22  172.79     35.50    100.00      100.00       10.30

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
high_humidity = weather_data[weather_data['Humidity']>=100]
high_humidity
# Out:
#          City    Lat    Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 62  ESPERANCE -33.87 121.90     14.00       100          90        5.10
# 71     TORBAY  47.67 -52.73      9.44       100          90        9.80
#
#    Country_Code Country_Name        UTC_DateTime
# 62           AU    Australia 2020-07-16 21:36:29
# 71           CA       Canada 2020-07-16 21:31:37

# %%
#  Get the indices of cities that have humidity over 100%.
index_label = weather_data.query('Humidity >=100').index.tolist() 
print(index_label, sep=',')
# Out:
# [62, 71]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data.drop(index_label, axis=0, inplace=False)
clean_city_data.shape
# Out:
# (84, 10)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Store plot data
lat = clean_city_data['Lat']
tem = clean_city_data['Max_Temp']
hum = clean_city_data['Humidity']
cld = clean_city_data['Cloudiness']
wnd = clean_city_data['Wind_Speed']
plot_date = weather_data['UTC_DateTime'][0].date().strftime("%d %b %Y ")

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
_= plt.plot(lat, tem, marker='.', markersize=14, color='darkblue', linestyle='none')
_ = plt.xlabel('Latitude')
_ = plt.ylabel('Max Temperature (F)')
_ = plt.title(f'City Latitude vs Temperature {plot_date}', size=14)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
_= plt.plot(lat, hum, marker='.', markersize=14, color='darkblue', linestyle='none')
_ = plt.xlabel('Latitude')
_ = plt.ylabel('Humidity (%)')
_ = plt.title(f'City Latitude vs Humidity {plot_date}', size=14)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
_= plt.plot(lat, cld, marker='.', markersize=14, color='darkblue', linestyle='none')
_ = plt.xlabel('Latitude')
_ = plt.ylabel('Cloudiness (%)')
_ = plt.title(f'City Latitude vs Cloudiness {plot_date}', size=14)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
_= plt.plot(lat, wnd, marker='.', markersize=14, color='darkblue', linestyle='none')
_ = plt.xlabel('Latitude')
_ = plt.ylabel('Wind Speed (mph)')
_ = plt.title(f'City Latitude vs Wind Speed {plot_date}', size=14)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
clean_city_data['Hemisphere'] = (
        np.select(
        condlist=[clean_city_data['Lat'] >= 0, clean_city_data['Lat'] < 0], 
        choicelist=['Northern', 'Southern'] 
       ))
clean_city_data['Hemisphere']= clean_city_data['Hemisphere'].astype('category')
clean_city_data.head()
# Out:
#          City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0    UMM LAJJ  25.02   37.27     28.02        72           0        2.50
# 1   GLADSTONE -23.85  151.25      9.00        57           0        2.60
# 2  SAN ANDRES  12.58  -81.70     30.00        74          20        4.10
# 3      PIERRE  44.37 -100.35     32.22        24           1        3.60
# 4  LAVRENTIYA  65.58 -171.00     10.63        77          99        2.01
#
#   Country_Code        Country_Name        UTC_DateTime Hemisphere
# 0           SA        Saudi Arabia 2020-07-16 21:34:27   Northern
# 1           AU           Australia 2020-07-16 21:36:18   Southern
# 2           CO            Colombia 2020-07-16 21:36:18   Northern
# 3           US       United States 2020-07-16 21:34:05   Northern
# 4           RU  Russian Federation 2020-07-16 21:36:19   Northern

# %%
# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index=False)

# %%
# Data Exploration
explore_data = clean_city_data.filter(['Lat', 'Max_Temp', 'Cloudiness', 'Wind_Speed', 'Hemisphere'])
g=sns.PairGrid(explore_data, hue='Hemisphere')
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()
print(' '*23,'Data exploration (Northern vs Southern Hemisphere)')
# Out:
#                         Data exploration (Northern vs Southern Hemisphere)

# %%
# Extract and Store Data for Regression Analysis
north_data = clean_city_data[clean_city_data['Hemisphere']=='Northern']
south_data = clean_city_data[clean_city_data['Hemisphere']=='Southern']

# %%
# Create Class DataAnalysis
class DataAnalysis():
    regress_values = None
    line_eq = None
  
    # Define initialization method
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    # Define linear regression method
    def lin_regr(self):
        (slope, intercept, rvalue, pvalue, stderr) = linregress(self.x, self.y)
        self.regress_values = self.x * slope + intercept
        self.line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        return self.regress_values, self.line_eq
    
    # Define scatter plot method
    def scat_plot(self):
        regress_values, line_eq = self.lin_regr()
        x_axes = np.min(self.x)+5
        plt.scatter(self.x, self.y)
        plt.plot(self.x, regress_values, "r-")
        plt.annotate(line_eq, (x_axes,10), fontsize=15,color="red")
        plt.title('Simple Linear Regression Analysis', size=14)
        plt.ylabel('Latitude')

# %%
# Regression Analysiss for the Northern Hemisphere
north_temp = DataAnalysis(north_data['Max_Temp'], north_data['Lat'])
north_hum = DataAnalysis(north_data['Humidity'], north_data['Lat'])
north_cld = DataAnalysis(north_data['Cloudiness'], north_data['Lat'])
north_wnd = DataAnalysis(north_data['Wind_Speed'], north_data['Lat'])
# using the variable axs for multiple Axes
plt.figure(figsize=(25, 4))
plt.subplot(131)
north_temp.scat_plot()
plt.subplot(132)
north_hum.scat_plot()
plt.figure(figsize=(25, 4))
plt.subplot(131)
north_cld.scat_plot()
plt.subplot(132)
north_wnd.scat_plot()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
